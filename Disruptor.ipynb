# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
Data =pd.read_excel('GBO Employee Count.xlsx')

# %%
Data = Data.head(20)

# %%
Data1 = Data.sort_values('EmployeeCount',ascending=True)

# %%
Data1.plot('GBO', 'EmployeeCount', 'bar', color='b')

# %%
Incident = pd.read_excel('Incident Count GBO.xlsx')
Incident = Incident.head(20)

# %%
Incident =Incident.sort_values('EmployeeCount', ascending = True)

# %%
Incident.plot('GBO', 'EmployeeCount', 'bar', color='m')

# %%
Office = pd.read_excel('Office Employee Count.xlsx')

# %%
Office = Office.head(20)

# %%
Office = Office.sort_values('EmployeeCount', ascending = 'True')
Office.plot('Office_Code', 'EmployeeCount', 'bar', color ='b')

# %%
Incident2 = pd.read_excel('Incident Count Office.xlsx')
Incident2 = Incident2.head(20)
Incident2 = Incident2.sort_values('EmployeeCount',ascending = 'True')

# %%
Incident2.plot('Office_Code','EmployeeCount', 'bar',color='m')

# %%
Incident.head(20).plot('GBO', 'EmployeeCount', 'bar' ,color = 'g')
